# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json

# Load the JSON file
with open('/content/drive/MyDrive/chatbot/dataset.json', 'r') as f:
    dataset = json.load(f)

# Now you can work with the dataset
print(dataset)
# Out:
# [{'question': 'What services does your IT company offer?', 'answer': 'We offer a wide range of IT services, including web development, app development, IT consulting, network solutions, and cybersecurity.'}, {'question': 'How can I get a quote for a project?', 'answer': 'You can get a quote by filling out our contact form on the website or by calling us at [phone number].'}, {'question': 'Do you provide IT support and maintenance?', 'answer': 'Yes, we offer comprehensive IT support and maintenance services to ensure your systems run smoothly.'}, {'question': 'What industries do you specialize in?', 'answer': 'We specialize in various industries including healthcare, finance, education, retail, and more.'}, {'question': 'How can I contact your customer support?', 'answer': 'You can contact our customer support by emailing [support email] or calling [support phone number].'}, {'question': 'What are your business hours?', 'answer': 'Our business hours are Monday to Friday, 9 AM to 6 PM.'}, {'question': 'Do you offer custom software development?', 'answer': 'Yes, we provide custom software development tailored to meet your specific business needs.'}, {'question': 'Can you help with cloud solutions and migration?', 'answer': 'Absolutely, we offer cloud solutions and migration services to help you move to and manage cloud infrastructure.'}, {'question': 'How experienced is your team?', 'answer': 'Our team consists of highly skilled professionals with extensive experience in various IT domains.'}, {'question': 'Where is your company located?', 'answer': 'We are located at [company address].'}, {'question': 'What is your approach to cybersecurity?', 'answer': 'We employ a multi-layered approach to cybersecurity, including risk assessments, intrusion detection, and regular updates.'}, {'question': 'Do you provide training for our employees?', 'answer': 'Yes, we offer training sessions to ensure your employees are proficient with the IT solutions we provide.'}, {'question': 'How long does it take to complete a project?', 'answer': 'The timeline for project completion varies based on the scope and complexity of the project. We provide an estimated timeline during the planning phase.'}, {'question': 'What is your pricing model?', 'answer': 'Our pricing model depends on the service and project requirements. We offer both fixed-price and hourly-rate options.'}, {'question': 'Can you integrate new solutions with our existing systems?', 'answer': 'Yes, we specialize in integrating new solutions with your existing IT infrastructure seamlessly.'}, {'question': 'Do you offer consultation services?', 'answer': 'Yes, we provide IT consultation services to help you identify and implement the best solutions for your business.'}, {'question': 'How can I schedule a consultation?', 'answer': 'You can schedule a consultation by filling out our contact form or calling us directly at [phone number].'}, {'question': 'Do you have any case studies or client testimonials?', 'answer': "Yes, you can find case studies and client testimonials on our website under the 'Our Work' section."}, {'question': 'What technologies do you use?', 'answer': 'We use a variety of technologies including Python, Java, JavaScript, React, Node.js, AWS, Azure, and more.'}, {'question': 'How do you ensure the quality of your services?', 'answer': 'We follow industry best practices and standards, conduct thorough testing, and have a dedicated quality assurance team.'}, {'question': 'Do you offer disaster recovery solutions?', 'answer': 'Yes, we provide comprehensive disaster recovery solutions to protect your data and ensure business continuity.'}, {'question': 'How do I start a project with your company?', 'answer': 'To start a project, simply contact us through our website or call us, and we will guide you through the initial steps.'}, {'question': 'Can you help us with IT compliance and regulations?', 'answer': 'Yes, we can assist you in ensuring your IT systems comply with relevan ...

# %%
questions=[]
questions = [item["question"] for item in dataset]
answers = [item["answer"] for item in dataset]
print("List of Questions:")
print(questions)
print("\nList of Answers:")
print(answers)
# Out:
# List of Questions:
# ['What services does your IT company offer?', 'How can I get a quote for a project?', 'Do you provide IT support and maintenance?', 'What industries do you specialize in?', 'How can I contact your customer support?', 'What are your business hours?', 'Do you offer custom software development?', 'Can you help with cloud solutions and migration?', 'How experienced is your team?', 'Where is your company located?', 'What is your approach to cybersecurity?', 'Do you provide training for our employees?', 'How long does it take to complete a project?', 'What is your pricing model?', 'Can you integrate new solutions with our existing systems?', 'Do you offer consultation services?', 'How can I schedule a consultation?', 'Do you have any case studies or client testimonials?', 'What technologies do you use?', 'How do you ensure the quality of your services?', 'Do you offer disaster recovery solutions?', 'How do I start a project with your company?', 'Can you help us with IT compliance and regulations?', 'What makes your IT company different from others?', 'How can I apply for a job at your IT company?', 'What positions are currently available?', 'What qualifications do you look for in candidates?', 'Do you offer internships or entry-level positions?', 'What is the recruitment process like?', 'How long does the recruitment process take?', 'Do you provide training for new employees?', 'What benefits do you offer to your employees?', 'Is remote work an option?', 'How do you support employee growth and development?', 'What is the company culture like?', 'Are there opportunities for advancement?', 'How can I prepare for the interview?', 'Do you offer part-time positions?', 'What is the dress code at your company?', 'How can I check the status of my application?', 'Do you hire international candidates?', 'What kind of projects will I be working on?', 'Can I apply for more than one position?', 'Who can I contact if I have questions about recruitment?', 'What is the work-life balance like at your company?', 'Do you provide relocation assistance?', 'What are the key values your company looks for in employees?', 'How do you handle employee performance reviews?', 'What products has your company developed?', 'Can you provide examples of successful projects?', 'What technologies do you use for web development?', 'What technologies do you use for mobile app development?', 'Do you develop cloud-based solutions?', 'What database technologies do you use?', 'What programming languages are your developers proficient in?', 'How do you ensure the scalability of your products?', 'What cybersecurity measures do you implement in your products?', 'Can you integrate your products with existing systems?', 'Do you use Agile methodologies in your development process?', 'What tools do you use for project management?', 'How do you handle data analytics and reporting in your products?', 'What kind of user interfaces do you design?', 'Do you offer IoT (Internet of Things) solutions?', 'What AI and machine learning technologies do you use?', 'Do you provide blockchain development services?', 'What DevOps practices do you follow?', 'How do you ensure the quality of your products?', 'What is your approach to UI/UX design?', 'Can you customize your products to meet specific client needs?', 'How do you stay updated with the latest technologies?', 'What industries have you developed products for?', 'Do you provide ongoing support and maintenance for your products?', 'How do you handle product updates and new features?', 'What companies or organizations have you collaborated with?', 'Can you provide examples of collaborative projects?', 'What type of projects have you completed through collaborations?', 'Have you worked with international partners?', 'Do you collaborate with tech startups?', 'How do you choose your collaboration partners?', 'Can you describe a particularly successful collaboration?', 'What industries have you collaborated with?', 'Do you collaborate with acade ...
#
# List of Answers:
# ['We offer a wide range of IT services, including web development, app development, IT consulting, network solutions, and cybersecurity.', 'You can get a quote by filling out our contact form on the website or by calling us at [phone number].', 'Yes, we offer comprehensive IT support and maintenance services to ensure your systems run smoothly.', 'We specialize in various industries including healthcare, finance, education, retail, and more.', 'You can contact our customer support by emailing [support email] or calling [support phone number].', 'Our business hours are Monday to Friday, 9 AM to 6 PM.', 'Yes, we provide custom software development tailored to meet your specific business needs.', 'Absolutely, we offer cloud solutions and migration services to help you move to and manage cloud infrastructure.', 'Our team consists of highly skilled professionals with extensive experience in various IT domains.', 'We are located at [company address].', 'We employ a multi-layered approach to cybersecurity, including risk assessments, intrusion detection, and regular updates.', 'Yes, we offer training sessions to ensure your employees are proficient with the IT solutions we provide.', 'The timeline for project completion varies based on the scope and complexity of the project. We provide an estimated timeline during the planning phase.', 'Our pricing model depends on the service and project requirements. We offer both fixed-price and hourly-rate options.', 'Yes, we specialize in integrating new solutions with your existing IT infrastructure seamlessly.', 'Yes, we provide IT consultation services to help you identify and implement the best solutions for your business.', 'You can schedule a consultation by filling out our contact form or calling us directly at [phone number].', "Yes, you can find case studies and client testimonials on our website under the 'Our Work' section.", 'We use a variety of technologies including Python, Java, JavaScript, React, Node.js, AWS, Azure, and more.', 'We follow industry best practices and standards, conduct thorough testing, and have a dedicated quality assurance team.', 'Yes, we provide comprehensive disaster recovery solutions to protect your data and ensure business continuity.', 'To start a project, simply contact us through our website or call us, and we will guide you through the initial steps.', 'Yes, we can assist you in ensuring your IT systems comply with relevant regulations and standards.', 'Our commitment to customer satisfaction, innovative solutions, and a highly skilled team sets us apart.', 'You can apply for a job by visiting our Careers page on our website and submitting your resume through the application form.', 'We have a variety of open positions. You can view all current openings on our Careers page.', 'We look for candidates with relevant experience, strong technical skills, and a passion for technology. Specific qualifications depend on the role.', 'Yes, we offer internships and entry-level positions. Please check our Careers page for available opportunities.', 'Our recruitment process typically includes an initial application review, a phone interview, technical assessments, and a final interview.', 'The recruitment process duration varies, but it generally takes about 2-4 weeks from application to offer.', 'Yes, we offer comprehensive onboarding and training programs to help new employees get up to speed.', 'We offer a competitive benefits package including health insurance, paid time off, retirement plans, and professional development opportunities.', 'Yes, we offer remote work options for many of our positions, depending on the role and project requirements.', 'We provide regular training sessions, mentorship programs, and opportunities for career advancement within the company.', 'Our company culture is collaborative, innovative, and focused on continuous learning and improvement.', 'Yes, we encourage career growth and offer opportunities for advancement based on perfor ...

# %%
# prompt: clean the dataset

# Remove duplicates from questions and answers
questions = list(dict.fromkeys(questions))
answers = list(dict.fromkeys(answers))

# Remove empty strings from questions and answers
questions = [q for q in questions if q]
answers = [a for a in answers if a]

# Print the cleaned dataset
print("Cleaned Questions:")
print(questions)
print("\nCleaned Answers:")
print(answers)
# Out:
# Cleaned Questions:
# ['What services does your IT company offer?', 'How can I get a quote for a project?', 'Do you provide IT support and maintenance?', 'What industries do you specialize in?', 'How can I contact your customer support?', 'What are your business hours?', 'Do you offer custom software development?', 'Can you help with cloud solutions and migration?', 'How experienced is your team?', 'Where is your company located?', 'What is your approach to cybersecurity?', 'Do you provide training for our employees?', 'How long does it take to complete a project?', 'What is your pricing model?', 'Can you integrate new solutions with our existing systems?', 'Do you offer consultation services?', 'How can I schedule a consultation?', 'Do you have any case studies or client testimonials?', 'What technologies do you use?', 'How do you ensure the quality of your services?', 'Do you offer disaster recovery solutions?', 'How do I start a project with your company?', 'Can you help us with IT compliance and regulations?', 'What makes your IT company different from others?', 'How can I apply for a job at your IT company?', 'What positions are currently available?', 'What qualifications do you look for in candidates?', 'Do you offer internships or entry-level positions?', 'What is the recruitment process like?', 'How long does the recruitment process take?', 'Do you provide training for new employees?', 'What benefits do you offer to your employees?', 'Is remote work an option?', 'How do you support employee growth and development?', 'What is the company culture like?', 'Are there opportunities for advancement?', 'How can I prepare for the interview?', 'Do you offer part-time positions?', 'What is the dress code at your company?', 'How can I check the status of my application?', 'Do you hire international candidates?', 'What kind of projects will I be working on?', 'Can I apply for more than one position?', 'Who can I contact if I have questions about recruitment?', 'What is the work-life balance like at your company?', 'Do you provide relocation assistance?', 'What are the key values your company looks for in employees?', 'How do you handle employee performance reviews?', 'What products has your company developed?', 'Can you provide examples of successful projects?', 'What technologies do you use for web development?', 'What technologies do you use for mobile app development?', 'Do you develop cloud-based solutions?', 'What database technologies do you use?', 'What programming languages are your developers proficient in?', 'How do you ensure the scalability of your products?', 'What cybersecurity measures do you implement in your products?', 'Can you integrate your products with existing systems?', 'Do you use Agile methodologies in your development process?', 'What tools do you use for project management?', 'How do you handle data analytics and reporting in your products?', 'What kind of user interfaces do you design?', 'Do you offer IoT (Internet of Things) solutions?', 'What AI and machine learning technologies do you use?', 'Do you provide blockchain development services?', 'What DevOps practices do you follow?', 'How do you ensure the quality of your products?', 'What is your approach to UI/UX design?', 'Can you customize your products to meet specific client needs?', 'How do you stay updated with the latest technologies?', 'What industries have you developed products for?', 'Do you provide ongoing support and maintenance for your products?', 'How do you handle product updates and new features?', 'What companies or organizations have you collaborated with?', 'Can you provide examples of collaborative projects?', 'What type of projects have you completed through collaborations?', 'Have you worked with international partners?', 'Do you collaborate with tech startups?', 'How do you choose your collaboration partners?', 'Can you describe a particularly successful collaboration?', 'What industries have you collaborated with?', 'Do you collaborate with acade ...
#
# Cleaned Answers:
# ['We offer a wide range of IT services, including web development, app development, IT consulting, network solutions, and cybersecurity.', 'You can get a quote by filling out our contact form on the website or by calling us at [phone number].', 'Yes, we offer comprehensive IT support and maintenance services to ensure your systems run smoothly.', 'We specialize in various industries including healthcare, finance, education, retail, and more.', 'You can contact our customer support by emailing [support email] or calling [support phone number].', 'Our business hours are Monday to Friday, 9 AM to 6 PM.', 'Yes, we provide custom software development tailored to meet your specific business needs.', 'Absolutely, we offer cloud solutions and migration services to help you move to and manage cloud infrastructure.', 'Our team consists of highly skilled professionals with extensive experience in various IT domains.', 'We are located at [company address].', 'We employ a multi-layered approach to cybersecurity, including risk assessments, intrusion detection, and regular updates.', 'Yes, we offer training sessions to ensure your employees are proficient with the IT solutions we provide.', 'The timeline for project completion varies based on the scope and complexity of the project. We provide an estimated timeline during the planning phase.', 'Our pricing model depends on the service and project requirements. We offer both fixed-price and hourly-rate options.', 'Yes, we specialize in integrating new solutions with your existing IT infrastructure seamlessly.', 'Yes, we provide IT consultation services to help you identify and implement the best solutions for your business.', 'You can schedule a consultation by filling out our contact form or calling us directly at [phone number].', "Yes, you can find case studies and client testimonials on our website under the 'Our Work' section.", 'We use a variety of technologies including Python, Java, JavaScript, React, Node.js, AWS, Azure, and more.', 'We follow industry best practices and standards, conduct thorough testing, and have a dedicated quality assurance team.', 'Yes, we provide comprehensive disaster recovery solutions to protect your data and ensure business continuity.', 'To start a project, simply contact us through our website or call us, and we will guide you through the initial steps.', 'Yes, we can assist you in ensuring your IT systems comply with relevant regulations and standards.', 'Our commitment to customer satisfaction, innovative solutions, and a highly skilled team sets us apart.', 'You can apply for a job by visiting our Careers page on our website and submitting your resume through the application form.', 'We have a variety of open positions. You can view all current openings on our Careers page.', 'We look for candidates with relevant experience, strong technical skills, and a passion for technology. Specific qualifications depend on the role.', 'Yes, we offer internships and entry-level positions. Please check our Careers page for available opportunities.', 'Our recruitment process typically includes an initial application review, a phone interview, technical assessments, and a final interview.', 'The recruitment process duration varies, but it generally takes about 2-4 weeks from application to offer.', 'Yes, we offer comprehensive onboarding and training programs to help new employees get up to speed.', 'We offer a competitive benefits package including health insurance, paid time off, retirement plans, and professional development opportunities.', 'Yes, we offer remote work options for many of our positions, depending on the role and project requirements.', 'We provide regular training sessions, mentorship programs, and opportunities for career advancement within the company.', 'Our company culture is collaborative, innovative, and focused on continuous learning and improvement.', 'Yes, we encourage career growth and offer opportunities for advancement based on perfor ...

# %%
# prompt: remove ponctuations

import string

def remove_punctuation(text):
  """
  Removes punctuation from a string.

  Args:
    text: The string to remove punctuation from.

  Returns:
    The string with punctuation removed.
  """

  # Create a translation table that maps punctuation characters to None.
  table = str.maketrans('', '', string.punctuation)

  # Use the translation table to remove punctuation from the string.
  return text.translate(table)

# Remove punctuation from questions and answers
questions = [remove_punctuation(q) for q in questions]
answers = [remove_punctuation(a) for a in answers]

# Print the cleaned dataset
print("Cleaned Questions:")
print(questions)
print("\nCleaned Answers:")
print(answers)
# Out:
# Cleaned Questions:
# ['What services does your IT company offer', 'How can I get a quote for a project', 'Do you provide IT support and maintenance', 'What industries do you specialize in', 'How can I contact your customer support', 'What are your business hours', 'Do you offer custom software development', 'Can you help with cloud solutions and migration', 'How experienced is your team', 'Where is your company located', 'What is your approach to cybersecurity', 'Do you provide training for our employees', 'How long does it take to complete a project', 'What is your pricing model', 'Can you integrate new solutions with our existing systems', 'Do you offer consultation services', 'How can I schedule a consultation', 'Do you have any case studies or client testimonials', 'What technologies do you use', 'How do you ensure the quality of your services', 'Do you offer disaster recovery solutions', 'How do I start a project with your company', 'Can you help us with IT compliance and regulations', 'What makes your IT company different from others', 'How can I apply for a job at your IT company', 'What positions are currently available', 'What qualifications do you look for in candidates', 'Do you offer internships or entrylevel positions', 'What is the recruitment process like', 'How long does the recruitment process take', 'Do you provide training for new employees', 'What benefits do you offer to your employees', 'Is remote work an option', 'How do you support employee growth and development', 'What is the company culture like', 'Are there opportunities for advancement', 'How can I prepare for the interview', 'Do you offer parttime positions', 'What is the dress code at your company', 'How can I check the status of my application', 'Do you hire international candidates', 'What kind of projects will I be working on', 'Can I apply for more than one position', 'Who can I contact if I have questions about recruitment', 'What is the worklife balance like at your company', 'Do you provide relocation assistance', 'What are the key values your company looks for in employees', 'How do you handle employee performance reviews', 'What products has your company developed', 'Can you provide examples of successful projects', 'What technologies do you use for web development', 'What technologies do you use for mobile app development', 'Do you develop cloudbased solutions', 'What database technologies do you use', 'What programming languages are your developers proficient in', 'How do you ensure the scalability of your products', 'What cybersecurity measures do you implement in your products', 'Can you integrate your products with existing systems', 'Do you use Agile methodologies in your development process', 'What tools do you use for project management', 'How do you handle data analytics and reporting in your products', 'What kind of user interfaces do you design', 'Do you offer IoT Internet of Things solutions', 'What AI and machine learning technologies do you use', 'Do you provide blockchain development services', 'What DevOps practices do you follow', 'How do you ensure the quality of your products', 'What is your approach to UIUX design', 'Can you customize your products to meet specific client needs', 'How do you stay updated with the latest technologies', 'What industries have you developed products for', 'Do you provide ongoing support and maintenance for your products', 'How do you handle product updates and new features', 'What companies or organizations have you collaborated with', 'Can you provide examples of collaborative projects', 'What type of projects have you completed through collaborations', 'Have you worked with international partners', 'Do you collaborate with tech startups', 'How do you choose your collaboration partners', 'Can you describe a particularly successful collaboration', 'What industries have you collaborated with', 'Do you collaborate with academic institutions', 'How do you manage collaborative projects', 'What role do you typical ...
#
# Cleaned Answers:
# ['We offer a wide range of IT services including web development app development IT consulting network solutions and cybersecurity', 'You can get a quote by filling out our contact form on the website or by calling us at phone number', 'Yes we offer comprehensive IT support and maintenance services to ensure your systems run smoothly', 'We specialize in various industries including healthcare finance education retail and more', 'You can contact our customer support by emailing support email or calling support phone number', 'Our business hours are Monday to Friday 9 AM to 6 PM', 'Yes we provide custom software development tailored to meet your specific business needs', 'Absolutely we offer cloud solutions and migration services to help you move to and manage cloud infrastructure', 'Our team consists of highly skilled professionals with extensive experience in various IT domains', 'We are located at company address', 'We employ a multilayered approach to cybersecurity including risk assessments intrusion detection and regular updates', 'Yes we offer training sessions to ensure your employees are proficient with the IT solutions we provide', 'The timeline for project completion varies based on the scope and complexity of the project We provide an estimated timeline during the planning phase', 'Our pricing model depends on the service and project requirements We offer both fixedprice and hourlyrate options', 'Yes we specialize in integrating new solutions with your existing IT infrastructure seamlessly', 'Yes we provide IT consultation services to help you identify and implement the best solutions for your business', 'You can schedule a consultation by filling out our contact form or calling us directly at phone number', 'Yes you can find case studies and client testimonials on our website under the Our Work section', 'We use a variety of technologies including Python Java JavaScript React Nodejs AWS Azure and more', 'We follow industry best practices and standards conduct thorough testing and have a dedicated quality assurance team', 'Yes we provide comprehensive disaster recovery solutions to protect your data and ensure business continuity', 'To start a project simply contact us through our website or call us and we will guide you through the initial steps', 'Yes we can assist you in ensuring your IT systems comply with relevant regulations and standards', 'Our commitment to customer satisfaction innovative solutions and a highly skilled team sets us apart', 'You can apply for a job by visiting our Careers page on our website and submitting your resume through the application form', 'We have a variety of open positions You can view all current openings on our Careers page', 'We look for candidates with relevant experience strong technical skills and a passion for technology Specific qualifications depend on the role', 'Yes we offer internships and entrylevel positions Please check our Careers page for available opportunities', 'Our recruitment process typically includes an initial application review a phone interview technical assessments and a final interview', 'The recruitment process duration varies but it generally takes about 24 weeks from application to offer', 'Yes we offer comprehensive onboarding and training programs to help new employees get up to speed', 'We offer a competitive benefits package including health insurance paid time off retirement plans and professional development opportunities', 'Yes we offer remote work options for many of our positions depending on the role and project requirements', 'We provide regular training sessions mentorship programs and opportunities for career advancement within the company', 'Our company culture is collaborative innovative and focused on continuous learning and improvement', 'Yes we encourage career growth and offer opportunities for advancement based on performance and potential', 'Prepare by reviewing the job description researching our company and being ready to disc ...

# %%
# prompt: lowercase

questions = [q.lower() for q in questions]
answers = [a.lower() for a in answers]

# Print the lowercase dataset
print("Lowercase Questions:")
print(questions)
print("\nLowercase Answers:")
print(answers)
# Out:
# Lowercase Questions:
# ['what services does your it company offer', 'how can i get a quote for a project', 'do you provide it support and maintenance', 'what industries do you specialize in', 'how can i contact your customer support', 'what are your business hours', 'do you offer custom software development', 'can you help with cloud solutions and migration', 'how experienced is your team', 'where is your company located', 'what is your approach to cybersecurity', 'do you provide training for our employees', 'how long does it take to complete a project', 'what is your pricing model', 'can you integrate new solutions with our existing systems', 'do you offer consultation services', 'how can i schedule a consultation', 'do you have any case studies or client testimonials', 'what technologies do you use', 'how do you ensure the quality of your services', 'do you offer disaster recovery solutions', 'how do i start a project with your company', 'can you help us with it compliance and regulations', 'what makes your it company different from others', 'how can i apply for a job at your it company', 'what positions are currently available', 'what qualifications do you look for in candidates', 'do you offer internships or entrylevel positions', 'what is the recruitment process like', 'how long does the recruitment process take', 'do you provide training for new employees', 'what benefits do you offer to your employees', 'is remote work an option', 'how do you support employee growth and development', 'what is the company culture like', 'are there opportunities for advancement', 'how can i prepare for the interview', 'do you offer parttime positions', 'what is the dress code at your company', 'how can i check the status of my application', 'do you hire international candidates', 'what kind of projects will i be working on', 'can i apply for more than one position', 'who can i contact if i have questions about recruitment', 'what is the worklife balance like at your company', 'do you provide relocation assistance', 'what are the key values your company looks for in employees', 'how do you handle employee performance reviews', 'what products has your company developed', 'can you provide examples of successful projects', 'what technologies do you use for web development', 'what technologies do you use for mobile app development', 'do you develop cloudbased solutions', 'what database technologies do you use', 'what programming languages are your developers proficient in', 'how do you ensure the scalability of your products', 'what cybersecurity measures do you implement in your products', 'can you integrate your products with existing systems', 'do you use agile methodologies in your development process', 'what tools do you use for project management', 'how do you handle data analytics and reporting in your products', 'what kind of user interfaces do you design', 'do you offer iot internet of things solutions', 'what ai and machine learning technologies do you use', 'do you provide blockchain development services', 'what devops practices do you follow', 'how do you ensure the quality of your products', 'what is your approach to uiux design', 'can you customize your products to meet specific client needs', 'how do you stay updated with the latest technologies', 'what industries have you developed products for', 'do you provide ongoing support and maintenance for your products', 'how do you handle product updates and new features', 'what companies or organizations have you collaborated with', 'can you provide examples of collaborative projects', 'what type of projects have you completed through collaborations', 'have you worked with international partners', 'do you collaborate with tech startups', 'how do you choose your collaboration partners', 'can you describe a particularly successful collaboration', 'what industries have you collaborated with', 'do you collaborate with academic institutions', 'how do you manage collaborative projects', 'what role do you typical ...
#
# Lowercase Answers:
# ['we offer a wide range of it services including web development app development it consulting network solutions and cybersecurity', 'you can get a quote by filling out our contact form on the website or by calling us at phone number', 'yes we offer comprehensive it support and maintenance services to ensure your systems run smoothly', 'we specialize in various industries including healthcare finance education retail and more', 'you can contact our customer support by emailing support email or calling support phone number', 'our business hours are monday to friday 9 am to 6 pm', 'yes we provide custom software development tailored to meet your specific business needs', 'absolutely we offer cloud solutions and migration services to help you move to and manage cloud infrastructure', 'our team consists of highly skilled professionals with extensive experience in various it domains', 'we are located at company address', 'we employ a multilayered approach to cybersecurity including risk assessments intrusion detection and regular updates', 'yes we offer training sessions to ensure your employees are proficient with the it solutions we provide', 'the timeline for project completion varies based on the scope and complexity of the project we provide an estimated timeline during the planning phase', 'our pricing model depends on the service and project requirements we offer both fixedprice and hourlyrate options', 'yes we specialize in integrating new solutions with your existing it infrastructure seamlessly', 'yes we provide it consultation services to help you identify and implement the best solutions for your business', 'you can schedule a consultation by filling out our contact form or calling us directly at phone number', 'yes you can find case studies and client testimonials on our website under the our work section', 'we use a variety of technologies including python java javascript react nodejs aws azure and more', 'we follow industry best practices and standards conduct thorough testing and have a dedicated quality assurance team', 'yes we provide comprehensive disaster recovery solutions to protect your data and ensure business continuity', 'to start a project simply contact us through our website or call us and we will guide you through the initial steps', 'yes we can assist you in ensuring your it systems comply with relevant regulations and standards', 'our commitment to customer satisfaction innovative solutions and a highly skilled team sets us apart', 'you can apply for a job by visiting our careers page on our website and submitting your resume through the application form', 'we have a variety of open positions you can view all current openings on our careers page', 'we look for candidates with relevant experience strong technical skills and a passion for technology specific qualifications depend on the role', 'yes we offer internships and entrylevel positions please check our careers page for available opportunities', 'our recruitment process typically includes an initial application review a phone interview technical assessments and a final interview', 'the recruitment process duration varies but it generally takes about 24 weeks from application to offer', 'yes we offer comprehensive onboarding and training programs to help new employees get up to speed', 'we offer a competitive benefits package including health insurance paid time off retirement plans and professional development opportunities', 'yes we offer remote work options for many of our positions depending on the role and project requirements', 'we provide regular training sessions mentorship programs and opportunities for career advancement within the company', 'our company culture is collaborative innovative and focused on continuous learning and improvement', 'yes we encourage career growth and offer opportunities for advancement based on performance and potential', 'prepare by reviewing the job description researching our company and being ready to disc ...

# %%
print(len(answers))
print(len(questions))
# Out:
# 178
# 178

# %%
# prompt: remove stopwords

import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Define a list of stopwords
stop_words = set(stopwords.words('english'))

# Remove stopwords from questions and answers
questions = [q for q in questions if q not in stop_words]
answers = [a for a in answers if a not in stop_words]

# Print the cleaned dataset
print("Questions without stopwords:")
print(questions)
print("\nAnswers without stopwords:")
print(answers)
# Out:
# Questions without stopwords:
# ['what services does your it company offer', 'how can i get a quote for a project', 'do you provide it support and maintenance', 'what industries do you specialize in', 'how can i contact your customer support', 'what are your business hours', 'do you offer custom software development', 'can you help with cloud solutions and migration', 'how experienced is your team', 'where is your company located', 'what is your approach to cybersecurity', 'do you provide training for our employees', 'how long does it take to complete a project', 'what is your pricing model', 'can you integrate new solutions with our existing systems', 'do you offer consultation services', 'how can i schedule a consultation', 'do you have any case studies or client testimonials', 'what technologies do you use', 'how do you ensure the quality of your services', 'do you offer disaster recovery solutions', 'how do i start a project with your company', 'can you help us with it compliance and regulations', 'what makes your it company different from others', 'how can i apply for a job at your it company', 'what positions are currently available', 'what qualifications do you look for in candidates', 'do you offer internships or entrylevel positions', 'what is the recruitment process like', 'how long does the recruitment process take', 'do you provide training for new employees', 'what benefits do you offer to your employees', 'is remote work an option', 'how do you support employee growth and development', 'what is the company culture like', 'are there opportunities for advancement', 'how can i prepare for the interview', 'do you offer parttime positions', 'what is the dress code at your company', 'how can i check the status of my application', 'do you hire international candidates', 'what kind of projects will i be working on', 'can i apply for more than one position', 'who can i contact if i have questions about recruitment', 'what is the worklife balance like at your company', 'do you provide relocation assistance', 'what are the key values your company looks for in employees', 'how do you handle employee performance reviews', 'what products has your company developed', 'can you provide examples of successful projects', 'what technologies do you use for web development', 'what technologies do you use for mobile app development', 'do you develop cloudbased solutions', 'what database technologies do you use', 'what programming languages are your developers proficient in', 'how do you ensure the scalability of your products', 'what cybersecurity measures do you implement in your products', 'can you integrate your products with existing systems', 'do you use agile methodologies in your development process', 'what tools do you use for project management', 'how do you handle data analytics and reporting in your products', 'what kind of user interfaces do you design', 'do you offer iot internet of things solutions', 'what ai and machine learning technologies do you use', 'do you provide blockchain development services', 'what devops practices do you follow', 'how do you ensure the quality of your products', 'what is your approach to uiux design', 'can you customize your products to meet specific client needs', 'how do you stay updated with the latest technologies', 'what industries have you developed products for', 'do you provide ongoing support and maintenance for your products', 'how do you handle product updates and new features', 'what companies or organizations have you collaborated with', 'can you provide examples of collaborative projects', 'what type of projects have you completed through collaborations', 'have you worked with international partners', 'do you collaborate with tech startups', 'how do you choose your collaboration partners', 'can you describe a particularly successful collaboration', 'what industries have you collaborated with', 'do you collaborate with academic institutions', 'how do you manage collaborative projects', 'what role do you typical ...
#
# Answers without stopwords:
# ['we offer a wide range of it services including web development app development it consulting network solutions and cybersecurity', 'you can get a quote by filling out our contact form on the website or by calling us at phone number', 'yes we offer comprehensive it support and maintenance services to ensure your systems run smoothly', 'we specialize in various industries including healthcare finance education retail and more', 'you can contact our customer support by emailing support email or calling support phone number', 'our business hours are monday to friday 9 am to 6 pm', 'yes we provide custom software development tailored to meet your specific business needs', 'absolutely we offer cloud solutions and migration services to help you move to and manage cloud infrastructure', 'our team consists of highly skilled professionals with extensive experience in various it domains', 'we are located at company address', 'we employ a multilayered approach to cybersecurity including risk assessments intrusion detection and regular updates', 'yes we offer training sessions to ensure your employees are proficient with the it solutions we provide', 'the timeline for project completion varies based on the scope and complexity of the project we provide an estimated timeline during the planning phase', 'our pricing model depends on the service and project requirements we offer both fixedprice and hourlyrate options', 'yes we specialize in integrating new solutions with your existing it infrastructure seamlessly', 'yes we provide it consultation services to help you identify and implement the best solutions for your business', 'you can schedule a consultation by filling out our contact form or calling us directly at phone number', 'yes you can find case studies and client testimonials on our website under the our work section', 'we use a variety of technologies including python java javascript react nodejs aws azure and more', 'we follow industry best practices and standards conduct thorough testing and have a dedicated quality assurance team', 'yes we provide comprehensive disaster recovery solutions to protect your data and ensure business continuity', 'to start a project simply contact us through our website or call us and we will guide you through the initial steps', 'yes we can assist you in ensuring your it systems comply with relevant regulations and standards', 'our commitment to customer satisfaction innovative solutions and a highly skilled team sets us apart', 'you can apply for a job by visiting our careers page on our website and submitting your resume through the application form', 'we have a variety of open positions you can view all current openings on our careers page', 'we look for candidates with relevant experience strong technical skills and a passion for technology specific qualifications depend on the role', 'yes we offer internships and entrylevel positions please check our careers page for available opportunities', 'our recruitment process typically includes an initial application review a phone interview technical assessments and a final interview', 'the recruitment process duration varies but it generally takes about 24 weeks from application to offer', 'yes we offer comprehensive onboarding and training programs to help new employees get up to speed', 'we offer a competitive benefits package including health insurance paid time off retirement plans and professional development opportunities', 'yes we offer remote work options for many of our positions depending on the role and project requirements', 'we provide regular training sessions mentorship programs and opportunities for career advancement within the company', 'our company culture is collaborative innovative and focused on continuous learning and improvement', 'yes we encourage career growth and offer opportunities for advancement based on performance and potential', 'prepare by reviewing the job description researching our company and being ready to disc ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download the punkt tokenizer data
nltk.download('punkt')

# Tokenize the questions and answers
questions_tokenized = [word_tokenize(q) for q in questions]
answers_tokenized = [word_tokenize(a) for a in answers]

# Print the tokenized dataset
print("Tokenized Questions:")
print(questions_tokenized)
print("\nTokenized Answers:")
print(answers_tokenized)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Tokenized Questions:
# [['what', 'services', 'does', 'your', 'it', 'company', 'offer'], ['how', 'can', 'i', 'get', 'a', 'quote', 'for', 'a', 'project'], ['do', 'you', 'provide', 'it', 'support', 'and', 'maintenance'], ['what', 'industries', 'do', 'you', 'specialize', 'in'], ['how', 'can', 'i', 'contact', 'your', 'customer', 'support'], ['what', 'are', 'your', 'business', 'hours'], ['do', 'you', 'offer', 'custom', 'software', 'development'], ['can', 'you', 'help', 'with', 'cloud', 'solutions', 'and', 'migration'], ['how', 'experienced', 'is', 'your', 'team'], ['where', 'is', 'your', 'company', 'located'], ['what', 'is', 'your', 'approach', 'to', 'cybersecurity'], ['do', 'you', 'provide', 'training', 'for', 'our', 'employees'], ['how', 'long', 'does', 'it', 'take', 'to', 'complete', 'a', 'project'], ['what', 'is', 'your', 'pricing', 'model'], ['can', 'you', 'integrate', 'new', 'solutions', 'with', 'our', 'existing', 'systems'], ['do', 'you', 'offer', 'consultation', 'services'], ['how', 'can', 'i', 'schedule', 'a', 'consultation'], ['do', 'you', 'have', 'any', 'case', 'studies', 'or', 'client', 'testimonials'], ['what', 'technologies', 'do', 'you', 'use'], ['how', 'do', 'you', 'ensure', 'the', 'quality', 'of', 'your', 'services'], ['do', 'you', 'offer', 'disaster', 'recovery', 'solutions'], ['how', 'do', 'i', 'start', 'a', 'project', 'with', 'your', 'company'], ['can', 'you', 'help', 'us', 'with', 'it', 'compliance', 'and', 'regulations'], ['what', 'makes', 'your', 'it', 'company', 'different', 'from', 'others'], ['how', 'can', 'i', 'apply', 'for', 'a', 'job', 'at', 'your', 'it', 'company'], ['what', 'positions', 'are', 'currently', 'available'], ['what', 'qualifications', 'do', 'you', 'look', 'for', 'in', 'candidates'], ['do', 'you', 'offer', 'internships', 'or', 'entrylevel', 'positions'], ['what', 'is', 'the', 'recruitment', 'process', 'like'], ['how', 'long', 'does', 'the', 'recruitment', 'process', 'take'], ['do', 'you', 'provide', 'training', 'for', 'new', 'employees'], ['what', 'benefits', 'do', 'you', 'offer', 'to', 'your', 'employees'], ['is', 'remote', 'work', 'an', 'option'], ['how', 'do', 'you', 'support', 'employee', 'growth', 'and', 'development'], ['what', 'is', 'the', 'company', 'culture', 'like'], ['are', 'there', 'opportunities', 'for', 'advancement'], ['how', 'can', 'i', 'prepare', 'for', 'the', 'interview'], ['do', 'you', 'offer', 'parttime', 'positions'], ['what', 'is', 'the', 'dress', 'code', 'at', 'your', 'company'], ['how', 'can', 'i', 'check', 'the', 'status', 'of', 'my', 'application'], ['do', 'you', 'hire', 'international', 'candidates'], ['what', 'kind', 'of', 'projects', 'will', 'i', 'be', 'working', 'on'], ['can', 'i', 'apply', 'for', 'more', 'than', 'one', 'position'], ['who', 'can', 'i', 'contact', 'if', 'i', 'have', 'questions', 'about', 'recruitment'], ['what', 'is', 'the', 'worklife', 'balance', 'like', 'at', 'your', 'company'], ['do', 'you', 'provide', 'relocation', 'assistance'], ['what', 'are', 'the', 'key', 'values', 'your', 'company', 'looks', 'for', 'in', 'employees'], ['how', 'do', 'you', 'handle', 'employee', 'performance', 'reviews'], ['what', 'products', 'has', 'your', 'company', 'developed'], ['can', 'you', 'provide', 'examples', 'of', 'successful', 'projects'], ['what', 'technologies', 'do', 'you', 'use', 'for', 'web', 'development'], ['what', 'technologies', 'do', 'you', 'use', 'for', 'mobile', 'app', 'development'], ['do', 'you', 'develop', 'cloudbased', 'solutions'], ['what', 'database', 'technologies', 'do', 'you', 'use'], ['what', 'programming', 'languages', 'are', 'your', 'developers', 'proficient', 'in'], ['how', 'do', 'you', 'ensure', 'the', 'scalability', 'of', 'your', 'products'], ['what', 'cybersecurity', 'measures', 'do', 'you', 'implement', 'in', 'your', 'products'], ['can', 'you', 'integrate', 'your', 'products', 'with', 'existing', 'systems'], ['do', 'you', 'use', 'agile', 'methodologies', 'in', 'your', 'development', 'process'], ['what', 'tools', 'do', 'you', 'use', 'for', 'project', 'mana ...
#
# Tokenized Answers:
# [['we', 'offer', 'a', 'wide', 'range', 'of', 'it', 'services', 'including', 'web', 'development', 'app', 'development', 'it', 'consulting', 'network', 'solutions', 'and', 'cybersecurity'], ['you', 'can', 'get', 'a', 'quote', 'by', 'filling', 'out', 'our', 'contact', 'form', 'on', 'the', 'website', 'or', 'by', 'calling', 'us', 'at', 'phone', 'number'], ['yes', 'we', 'offer', 'comprehensive', 'it', 'support', 'and', 'maintenance', 'services', 'to', 'ensure', 'your', 'systems', 'run', 'smoothly'], ['we', 'specialize', 'in', 'various', 'industries', 'including', 'healthcare', 'finance', 'education', 'retail', 'and', 'more'], ['you', 'can', 'contact', 'our', 'customer', 'support', 'by', 'emailing', 'support', 'email', 'or', 'calling', 'support', 'phone', 'number'], ['our', 'business', 'hours', 'are', 'monday', 'to', 'friday', '9', 'am', 'to', '6', 'pm'], ['yes', 'we', 'provide', 'custom', 'software', 'development', 'tailored', 'to', 'meet', 'your', 'specific', 'business', 'needs'], ['absolutely', 'we', 'offer', 'cloud', 'solutions', 'and', 'migration', 'services', 'to', 'help', 'you', 'move', 'to', 'and', 'manage', 'cloud', 'infrastructure'], ['our', 'team', 'consists', 'of', 'highly', 'skilled', 'professionals', 'with', 'extensive', 'experience', 'in', 'various', 'it', 'domains'], ['we', 'are', 'located', 'at', 'company', 'address'], ['we', 'employ', 'a', 'multilayered', 'approach', 'to', 'cybersecurity', 'including', 'risk', 'assessments', 'intrusion', 'detection', 'and', 'regular', 'updates'], ['yes', 'we', 'offer', 'training', 'sessions', 'to', 'ensure', 'your', 'employees', 'are', 'proficient', 'with', 'the', 'it', 'solutions', 'we', 'provide'], ['the', 'timeline', 'for', 'project', 'completion', 'varies', 'based', 'on', 'the', 'scope', 'and', 'complexity', 'of', 'the', 'project', 'we', 'provide', 'an', 'estimated', 'timeline', 'during', 'the', 'planning', 'phase'], ['our', 'pricing', 'model', 'depends', 'on', 'the', 'service', 'and', 'project', 'requirements', 'we', 'offer', 'both', 'fixedprice', 'and', 'hourlyrate', 'options'], ['yes', 'we', 'specialize', 'in', 'integrating', 'new', 'solutions', 'with', 'your', 'existing', 'it', 'infrastructure', 'seamlessly'], ['yes', 'we', 'provide', 'it', 'consultation', 'services', 'to', 'help', 'you', 'identify', 'and', 'implement', 'the', 'best', 'solutions', 'for', 'your', 'business'], ['you', 'can', 'schedule', 'a', 'consultation', 'by', 'filling', 'out', 'our', 'contact', 'form', 'or', 'calling', 'us', 'directly', 'at', 'phone', 'number'], ['yes', 'you', 'can', 'find', 'case', 'studies', 'and', 'client', 'testimonials', 'on', 'our', 'website', 'under', 'the', 'our', 'work', 'section'], ['we', 'use', 'a', 'variety', 'of', 'technologies', 'including', 'python', 'java', 'javascript', 'react', 'nodejs', 'aws', 'azure', 'and', 'more'], ['we', 'follow', 'industry', 'best', 'practices', 'and', 'standards', 'conduct', 'thorough', 'testing', 'and', 'have', 'a', 'dedicated', 'quality', 'assurance', 'team'], ['yes', 'we', 'provide', 'comprehensive', 'disaster', 'recovery', 'solutions', 'to', 'protect', 'your', 'data', 'and', 'ensure', 'business', 'continuity'], ['to', 'start', 'a', 'project', 'simply', 'contact', 'us', 'through', 'our', 'website', 'or', 'call', 'us', 'and', 'we', 'will', 'guide', 'you', 'through', 'the', 'initial', 'steps'], ['yes', 'we', 'can', 'assist', 'you', 'in', 'ensuring', 'your', 'it', 'systems', 'comply', 'with', 'relevant', 'regulations', 'and', 'standards'], ['our', 'commitment', 'to', 'customer', 'satisfaction', 'innovative', 'solutions', 'and', 'a', 'highly', 'skilled', 'team', 'sets', 'us', 'apart'], ['you', 'can', 'apply', 'for', 'a', 'job', 'by', 'visiting', 'our', 'careers', 'page', 'on', 'our', 'website', 'and', 'submitting', 'your', 'resume', 'through', 'the', 'application', 'form'], ['we', 'have', 'a', 'variety', 'of', 'open', 'positions', 'you', 'can', 'view', 'all', 'current', 'openings', 'on', 'our', 'careers', 'page'], ['we', 'look', 'for', 'candidates' ...

# %%
# prompt: vectorize the dataset

from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TfidfVectorizer object
vectorizer = TfidfVectorizer()

# Vectorize the questions and answers
questions_vectorized = vectorizer.fit_transform(questions)
answers_vectorized = vectorizer.transform(answers)

# Print the vectorized dataset
print("Vectorized Questions:")
print(questions_vectorized)
print("\nVectorized Answers:")
print(answers_vectorized)
# Out:
# Vectorized Questions:
#   (0, 201)	0.341726909785553
#   (0, 53)	0.3470319167415306
#   (0, 157)	0.4466611922120919
#   (0, 362)	0.2716652792853153
#   (0, 92)	0.4338545162336423
#   (0, 283)	0.49776519165396127
#   (0, 349)	0.23126477469555864
#   (1, 247)	0.4306360229590634
#   (1, 116)	0.2394827635035763
#   (1, 256)	0.5578287516501209
#   (1, 118)	0.5578287516501209
#   (1, 34)	0.2701732691231735
#   (1, 132)	0.24871910668648617
#   (2, 175)	0.5514722231438288
#   (2, 14)	0.3925647456393074
#   (2, 302)	0.41066845710211175
#   (2, 250)	0.3307345933559274
#   (2, 361)	0.16515065530695627
#   (2, 91)	0.19564742512841493
#   (2, 157)	0.4451794029077643
#   (3, 136)	0.38836106151799094
#   (3, 291)	0.6361474757359293
#   (3, 141)	0.5558918007825778
#   (3, 361)	0.17644935357585168
#   (3, 91)	0.2090325444275398
#   :	:
#   (175, 318)	0.34803523178506973
#   (175, 233)	0.39735255005018977
#   (175, 15)	0.34253040097675874
#   (175, 20)	0.31032297452927393
#   (175, 116)	0.2531420344231524
#   (176, 311)	0.43055263284782447
#   (176, 143)	0.3587480728406926
#   (176, 273)	0.3587480728406926
#   (176, 0)	0.2901425033429868
#   (176, 190)	0.3587480728406926
#   (176, 317)	0.19385889314297503
#   (176, 302)	0.29696109641941787
#   (176, 250)	0.2391596086046256
#   (176, 361)	0.11942314737395228
#   (176, 34)	0.20852961056952893
#   (176, 157)	0.3219165273216005
#   (177, 73)	0.4535746012731762
#   (177, 108)	0.4535746012731762
#   (177, 319)	0.3779305982173597
#   (177, 233)	0.3056566380647588
#   (177, 294)	0.4201015966799426
#   (177, 317)	0.20422467185716217
#   (177, 156)	0.25561734705967426
#   (177, 116)	0.1947251708460937
#   (177, 349)	0.17558888430281389
#
# Vectorized Answers:
#   (0, 347)	0.29560280993038635
#   (0, 289)	0.23649491496928102
#   (0, 283)	0.2463042385489282
#   (0, 257)	0.29560280993038635
#   (0, 201)	0.169093355095271
#   (0, 199)	0.17447807781933786
#   (0, 194)	0.29560280993038635
#   (0, 157)	0.44203390145302146
#   (0, 85)	0.41802261789398076
#   (0, 70)	0.25830988032844854
#   (0, 16)	0.29560280993038635
#   (0, 14)	0.19489550162747385
#   (1, 361)	0.10468798580217975
#   (1, 341)	0.3774284040054977
#   (1, 317)	0.16993939197925195
#   (1, 256)	0.3774284040054977
#   (1, 214)	0.3495748543018098
#   (1, 211)	0.2345805308374773
#   (1, 203)	0.32981244628282425
#   (1, 118)	0.3774284040054977
#   (1, 60)	0.3495748543018098
#   (1, 34)	0.18279994616352271
#   (1, 23)	0.3019588965791363
#   (2, 362)	0.19675497687577315
#   (2, 324)	0.273994339049908
#   :	:
#   (175, 201)	0.21208668350253795
#   (175, 114)	0.3707621719188424
#   (175, 14)	0.48889846140252524
#   (176, 324)	0.2169117545527019
#   (176, 310)	0.34252658424723603
#   (176, 302)	0.2362477017921487
#   (176, 288)	0.2993138022167385
#   (176, 250)	0.1902636694691907
#   (176, 157)	0.5122020403724818
#   (176, 102)	0.2487580881373823
#   (176, 99)	0.1902636694691907
#   (176, 22)	0.2993138022167385
#   (176, 14)	0.45166614264141347
#   (177, 355)	0.3070190556398435
#   (177, 324)	0.1944259076600109
#   (177, 317)	0.2764743251317097
#   (177, 294)	0.5687231830152041
#   (177, 232)	0.24562840074014466
#   (177, 201)	0.17562377775958435
#   (177, 195)	0.21708337179225237
#   (177, 156)	0.17302423080819115
#   (177, 128)	0.2682858648723861
#   (177, 124)	0.19828124189182583
#   (177, 108)	0.3070190556398435
#   (177, 73)	0.3070190556398435

# %%
# prompt: test the retrievel system
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
def retrieve_answer(question):
  """
  Retrieves the answer to a question from the dataset.

  Args:
    question: The question to retrieve the answer for.

  Returns:
    The answer to the question.
  """

  # Vectorize the question
  question_vectorized = vectorizer.transform([question])

  # Find the most similar question in the dataset
  similarity_scores = cosine_similarity(question_vectorized, questions_vectorized)
  most_similar_index = np.argmax(similarity_scores)

  # Return the answer to the most similar question
  return answers[most_similar_index]

# Test the retrieval system
question = "how i can contact you"
answer = retrieve_answer(question)
print("Question:", question)
print("Answer:", answer)
# Out:
# Question: how i can contact you
# Answer: you can contact our customer support by emailing support email or calling support phone number

# %%
# prompt: save the model so i can use it

import pickle

# Save the vectorizer and the questions and answers lists to a file
with open('chatbot.pkl', 'wb') as f:
  pickle.dump((vectorizer, questions, answers), f)

# Load the model
with open('chatbot_model.pkl', 'rb') as f:
  vectorizer, questions, answers = pickle.load(f)
